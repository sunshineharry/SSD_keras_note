# %% [markdown]
# # SSD 目标检测网络

# %% [markdown]
# ## SSD 的工作方式

# %% [markdown]
# - 在SSD中确定一个物体的位置，在图片上画出这个框需要四个参数：分别是中心点的x轴、y轴坐标、框的高和宽

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - 利用SSD确定参数

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 总结而言，SSD不过是把一-张图片划分成不同的网格，当某一个物体的中心点落在这个区域，这个物体就由这个网格来确定。

# %% [markdown]
# # SSD整体结构介绍
